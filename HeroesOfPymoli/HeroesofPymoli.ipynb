# %%
#Import Libraries
import pandas as pd
import os

#Set Directory
os.chdir("C:\\UTSADBC\\pandas-challenge\\HeroesOfPymoli\\Resources")

#Import Purchase Data CSV File
df = pd.read_csv("purchase_data.csv")

# %%
# Find Unique Values Among Players
total_players = (df['SN'].nunique())

# Establish Data Frame Display Showing Total Number of Players
table_player = pd.DataFrame({"Total Players":[total_players]})

#Display Data Frame
table_player
# Out:
#    Total Players
# 0            576

# %%
#Count unique items
unique_items = df['Item ID'].nunique()

#Find average, number of purchases and 
avg_price = df['Price'].mean()
purchases = len(df['Price'])
revenue = sum(df['Price'])

#Establish Data Frame Display Showing Purchase Data
pur_analysis = pd.DataFrame({"Number of Unique Items" : [unique_items], "Average Price" : avg_price, "Number of Purchases" : purchases, "Total Revenue" : revenue})

#Formatting and Display
pd.set_option("display.precision", 2)
pur_analysis.style.format({'Average Price':"${:,.2f}",'Total Revenue': '${:,.2f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_2ea39_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Unique Items</th>        <th class="col_heading level0 col1" >Average Price</th>        <th class="col_heading level0 col2" >Number of Purchases</th>        <th class="col_heading level0 col3" >Total Revenue</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2ea39_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2ea39_row0_col0" class="data row0 col0" >179</td>
#                         <td id="T_2ea39_row0_col1" class="data row0 col1" >$3.05</td>
#                         <td id="T_2ea39_row0_col2" class="data row0 col2" >780</td>
#                         <td id="T_2ea39_row0_col3" class="data row0 col3" >$2,379.77</td>
#             </tr>
#     </tbody></table>

# %%
#Establish Group by Gender
gender = df.groupby('Gender')

#Count Gender Uniques & Calculate Percentage
total_unique = gender.nunique()['SN']
percent = total_unique / total_players

#Establish Data Frame Display Gender Stats
gender_display = pd.DataFrame({"Total Count" : total_unique, "Percentage of Players" : percent.apply('{:.02%}'.format)})

#Formating and Display
gender_display.index.name = None
gender_display.sort_values(by='Total Count', ascending=False)
# Out:
#                        Total Count Percentage of Players
# Male                           484                84.03%
# Female                          81                14.06%
# Other / Non-Disclosed           11                 1.91%

# %%
#Used Gender Groups to Calculate Purchase Data 
purchase_count = gender.count()['SN']
purchase_avg = gender.mean()['Price']
purchase_eval = gender.sum()['Price']
avg_pp = purchase_eval / total_unique

#Establish Data Frame Displaying Purchase Stats by Gender
paby_gender = pd.DataFrame({"Purchase Count" : purchase_count, "Average Purchase Price" : purchase_avg, "Total Purchase Value" : purchase_eval, "Avg Total Purchase Per Person" : avg_pp}) 
paby_gender.style.format({'Average Purchase Price':"${:,.2f}",'Total Purchase Value': '${:,.2f}', 'Avg Total Purchase Per Person': '${:,.2f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_eee2f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Total Purchase Per Person</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eee2f_level0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_eee2f_row0_col0" class="data row0 col0" >113</td>
#                         <td id="T_eee2f_row0_col1" class="data row0 col1" >$3.20</td>
#                         <td id="T_eee2f_row0_col2" class="data row0 col2" >$361.94</td>
#                         <td id="T_eee2f_row0_col3" class="data row0 col3" >$4.47</td>
#             </tr>
#             <tr>
#                         <th id="T_eee2f_level0_row1" class="row_heading level0 row1" >Male</th>
#                         <td id="T_eee2f_row1_col0" class="data row1 col0" >652</td>
#                         <td id="T_eee2f_row1_col1" class="data row1 col1" >$3.02</td>
#                         <td id="T_eee2f_row1_col2" class="data row1 col2" >$1,967.64</td>
#                         <td id="T_eee2f_row1_col3" class="data row1 col3" >$4.07</td>
#             </tr>
#             <tr>
#                         <th id="T_eee2f_level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_eee2f_row2_col0" class="data row2 col0" >15</td>
#                         <td id="T_eee2f_row2_col1" class="data row2 col1" >$3.35</td>
#                         <td id="T_eee2f_row2_col2" class="data row2 col2" >$50.19</td>
#                         <td id="T_eee2f_row2_col3" class="data row2 col3" >$4.56</td>
#             </tr>
#     </tbody></table>

# %%
#Establish Dataframe with Bins and Label Bins
df['Age Group'] = pd.cut(df['Age'],[0, 9, 14, 19, 24, 29, 34, 39, 100], labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"])

# Group by Age and Bin
age_group = df.groupby('Age Group')

#Count by Customer and Age Group with Percentages 
count_age = age_group['SN'].nunique()
per = count_age / total_players

#Establish Data Frame Display Age Demographics
age_demo = pd.DataFrame({"Total Count" : count_age, "Percentage of Players" : per.apply('{:.02%}'.format)})
age_demo
# Out:
#            Total Count Percentage of Players
# Age Group
# <10                 17                 2.95%
# 10-14               22                 3.82%
# 15-19              107                18.58%
# 20-24              258                44.79%
# 25-29               77                13.37%
# 30-34               52                 9.03%
# 35-39               31                 5.38%
# 40+                 12                 2.08%

# %%
#Using Bins from Previous Table to Calculate Purchase by Age Group Stats
count_age1 = age_group['Purchase ID'].nunique()
purchase_avg2 = age_group.mean()['Price'] 
pur_ag = age_group.sum()['Price']
avg_pp = pur_ag / count_age 

#Establish Data Frame Display Age Analysis
age_analysis = pd.DataFrame({"Purchase Count" : count_age1, "Average Purchase Price" : purchase_avg2, "Total Purchase Value" : pur_ag, "Avg Total Purchase Per Person" : avg_pp})
age_analysis.style.format({'Average Purchase Price':"${:,.2f}",'Total Purchase Value': '${:,.2f}', 'Avg Total Purchase Per Person': '${:,.2f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_9c164_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Total Purchase Per Person</th>    </tr>    <tr>        <th class="index_name level0" >Age Group</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9c164_level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_9c164_row0_col0" class="data row0 col0" >23</td>
#                         <td id="T_9c164_row0_col1" class="data row0 col1" >$3.35</td>
#                         <td id="T_9c164_row0_col2" class="data row0 col2" >$77.13</td>
#                         <td id="T_9c164_row0_col3" class="data row0 col3" >$4.54</td>
#             </tr>
#             <tr>
#                         <th id="T_9c164_level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_9c164_row1_col0" class="data row1 col0" >28</td>
#                         <td id="T_9c164_row1_col1" class="data row1 col1" >$2.96</td>
#                         <td id="T_9c164_row1_col2" class="data row1 col2" >$82.78</td>
#                         <td id="T_9c164_row1_col3" class="data row1 col3" >$3.76</td>
#             </tr>
#             <tr>
#                         <th id="T_9c164_level0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_9c164_row2_col0" class="data row2 col0" >136</td>
#                         <td id="T_9c164_row2_col1" class="data row2 col1" >$3.04</td>
#                         <td id="T_9c164_row2_col2" class="data row2 col2" >$412.89</td>
#                         <td id="T_9c164_row2_col3" class="data row2 col3" >$3.86</td>
#             </tr>
#             <tr>
#                         <th id="T_9c164_level0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_9c164_row3_col0" class="data row3 col0" >365</td>
#                         <td id="T_9c164_row3_col1" class="data row3 col1" >$3.05</td>
#                         <td id="T_9c164_row3_col2" class="data row3 col2" >$1,114.06</td>
#                         <td id="T_9c164_row3_col3" class="data row3 col3" >$4.32</td>
#             </tr>
#             <tr>
#                         <th id="T_9c164_level0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_9c164_row4_col0" class="data row4 col0" >101</td>
#                         <td id="T_9c164_row4_col1" class="data row4 col1" >$2.90</td>
#                         <td id="T_9c164_row4_col2" class="data row4 col2" >$293.00</td>
#                         <td id="T_9c164_row4_col3" class="data row4 col3" >$3.81</td>
#             </tr>
#             <tr>
#                         <th id="T_9c164_level0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_9c164_row5_col0" class="data row5 col0" >73</td>
#                         <td id="T_9c164_row5_col1" class="data row5 col1" >$2.93</td>
#                         <td id="T_9c164_row5_col2" class="data row5 col2" >$214.00</td>
#                         <td id="T_9c164_row5_col3" class="data row5 col3" >$4.12</td>
#             </tr>
#             <tr>
#                         <th id="T_9c164_level0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_9c164_row6_col0" class="data row6 col0" >41</td>
#                         <td id="T_9c164_row6_col1" class="data row6 col1" >$3.60</td>
#                         <td id="T_9c164_row6_col2" class="data row6 col2" >$147.67</td>
#                         <td id="T_9c164_row6_col3" class="data row6 col3" >$4.76</td>
#             </tr>
#             <tr>
#                         <th id="T_9c164_level0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_9c164_row7_col0" class="data row7 col0" >13</td>
#                         <td id="T_9c164_row7_col1" class="data row7 col1" >$2.94</td>
#                         <td id="T_9c164_row7_col2" class="data row7 col2" >$38.24</td>
#                         <td id="T_9c164_row7_col3" class="data row7 col3" >$3.19</td>
#             </tr>
#     </tbody></table>

# %%
#Group By User
user_purchase = df.groupby('SN')

#Calculate User Purchase Stats
count_purchase = user_purchase.nunique()['Item ID']
avg_user_purchase = user_purchase.mean()['Price']
sum_purchase = user_purchase.sum()['Price']

#Establish Data Frame Display for User Purchase Stats
purchase_analysis = pd.DataFrame({"Purchase Count" : count_purchase, "Average Purchase Price" : avg_user_purchase, "Total Purchase Value" : sum_purchase})

#Sort
purchase_analysis.sort_values(['Total Purchase Value'], ascending=False, inplace = True)

#Format
purchase_analysis["Average Purchase Price"] = purchase_analysis ["Average Purchase Price"].map("${:,.2f}".format)
purchase_analysis["Total Purchase Value"] = purchase_analysis ["Total Purchase Value"].map("${:,.2f}".format)
purchase_analysis.head(5)
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %%
#Establish Data Frame
col = df[['Item ID', 'Item Name', 'Price']]

#Establish Groups
most_items = col.groupby(["Item ID","Item Name"])

#Calculate Stats
p_count = most_items['Price'].count()
tpv = most_items.sum()['Price']
avg_pp = tpv / p_count

#Establish Data Frame Display Product Sales
item_analysis = pd.DataFrame({"Purchase Count" : p_count, "Item Price" : avg_pp, "Total Purchase Value" : tpv})

#Sort
item_analysis.sort_values(['Purchase Count'], ascending=False, inplace = True)

#Format
item_analysis["Item Price"] = item_analysis ["Item Price"].map("${:,.2f}".format)
item_analysis["Total Purchase Value"] = item_analysis ["Total Purchase Value"].map("${:,.2f}".format)
item_analysis.head(5)
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 132     Persuasion                                                 9
# 108     Extraction, Quickblade Of Trembling Hands                  9
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 132     Persuasion                                        $3.22
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
#
#                                                      Total Purchase Value
# Item ID Item Name
# 92      Final Critic                                               $59.99
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 145     Fiery Glass Crusader                                       $41.22
# 132     Persuasion                                                 $28.99
# 108     Extraction, Quickblade Of Trembling Hands                  $31.77

# %%
#Establish Data Frame
col2 = df[['Item ID', 'Item Name', 'Price']]

#Establish Groups
most_items2 = col2.groupby(["Item ID","Item Name"])

#Calculate Stats
p_count2 = most_items2['Price'].count()
tpv2 = most_items2.sum()['Price']
avg_pp2 = tpv2 / p_count2

#Establish Data Frame Display Product Sales
item_analysis2 = pd.DataFrame({"Purchase Count" : p_count2, "Item Price" : avg_pp2, "Total Purchase Value" : tpv2})

#Sort 
item_analysis2.sort_values(['Total Purchase Value'], ascending=False, inplace = True)

#Format
item_analysis2["Item Price"] = item_analysis2 ["Item Price"].map("${:,.2f}".format)
item_analysis2["Total Purchase Value"] = item_analysis2 ["Total Purchase Value"].map("${:,.2f}".format)
item_analysis2.head(5)
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 103     Singed Scalpel                                             8
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# 92      Final Critic                                               $59.99
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 82      Nirvana                                                    $44.10
# 145     Fiery Glass Crusader                                       $41.22
# 103     Singed Scalpel                                             $34.80
